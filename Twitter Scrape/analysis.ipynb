# %%
import pandas as pd

# %%
df = pd.read_csv("tweets_aam_aadmi.csv")

# %%
alltxt = df['tweet'].to_list()

# %%
allwrds = {}
for txt in alltxt:
    l = txt.split()
    for w in l:
        if w in allwrds:
            allwrds[w] += 1
        else:
            allwrds[w] = 1

# %%
sorted_wrds = sorted(allwrds.items(), key=lambda x: x[1], reverse=True)

# %%
sorted_wrds = [w for w in sorted_wrds if w[0][0] == '@' or w[0][0] == '#']

# %%
sorted_wrds
# Out:
# [('@AamAadmiParty', 747),
#  ('@ArvindKejriwal', 348),
#  ('@BhagwantMann', 91),
#  ('@INCIndia', 90),
#  ('#AAPdePaap', 80),
#  ('@raghav_chadha', 71),
#  ('@AAPPunjab', 67),
#  ('@DrKumarVishwas', 53),
#  ('#KaamKiRajneeti', 49),
#  ('@BJP4India', 45),
#  ('#Punjab', 33),
#  ('#PunjabElections2022', 28),
#  ('@RahulGandhi', 28),
#  ('@karamjitrintu', 27),
#  ('#ArvindKejriwal', 27),
#  ('#AamAadmiParty', 26),
#  ('@CHARANJITCHANNI', 25),
#  ('@msisodia', 22),
#  ('#KejriwalSupportsKhalistan', 20),
#  ('#PunjabElections', 19),
#  ('@rahulkanwal', 19),
#  ('@rishikeshlaw', 17),
#  ('@INCPunjab', 17),
#  ('#AAP', 16),
#  ('@DrAshwani_Kumar', 16),
#  ('#KumarVishwas', 15),
#  ('@capt_amarinder', 15),
#  ('@kapsology', 15),
#  ('@AnshumanSail', 14),
#  ('@ANI', 14),
#  ('@AAPDelhi', 14),
#  ('@narendramodi', 14),
#  ('@AamAadmiParty.', 12),
#  ('@MeghBulletin', 11),
#  ('@ABPNews', 11),
#  ('@awasthis', 10),
#  ('@Simi_Garewal', 10),
#  ('@PMOIndia', 10),
#  ('@ndtv', 10),
#  ('@attorneybharti', 10),
#  ('@AAPTN', 10),
#  ('#AssemblyElections2022', 9),
#  ('@xt89_t', 9),
#  ('@analyst_epw', 8),
#  ('@_YogendraYadav', 8),
#  ('@SanjayAzadSln', 8),
#  ('@Jasmine441', 8),
#  ('@IndiaToday', 8),
#  ('@AtishiAAP', 8),
#  ('@CMODelhi', 8),
#  ('@PrannoyRoyNDTV', 7),
#  ('#Congress', 7),
#  ('@newsDelhiTimes', 7),
#  ('@vajinkya16', 6),
#  ('@AAPUttarPradesh', 6),
#  ('@pbhushan1', 6),
#  ('@aajtak', 6),
#  ('@AamAadmiParty,', 5),
#  ('@ARanganathan72', 5),
#  ('#BJP', 5),
#  ('#EkMaukaKejriwalKo', 5),
#  ('#Punjab_With_Modi', 5),
#  ("@AamAadmiParty's", 5),
#  ('@newslaundry', 5),
#  ('@AAPMumbai', 5),
#  ('@vijnad', 5),
#  ('@manaman_chhina', 5),
#  ('@SreenivasanJain', 5),
#  ('@The_veenaD', 5),
#  ('@Akali_Dal_', 5),
#  ('#Delhi', 5),
#  ('@AmitShah', 5),
#  ('#PunjabElection2022', 5),
#  ('@BJP4Punjab', 5),
#  ('@priyankagandhi', 5),
#  ('@OpIndia_com', 5),
#  ('#KaamKiRajneeti.', 5),
#  ('@Arun2981', 5),
#  ('@PreetiSMenon', 5),
#  ('@AAPMaharashtra', 4),
#  ('@sardesairajdeep', 4),
#  ('@IndianExpress', 4),
#  ('#RahulGandhi', 4),
#  ('@mmvp2005', 4),
#  ('#KejriwalVsAnganwadiWorkers', 4),
#  ('#kaamkirajneeti', 4),
#  ('#EkMaukaAAPNu', 4),
#  ('@SatyendarJain', 4),
#  ('#kaamKiRajneeti', 4),
#  ('@rssurjewala', 4),
#  ('@thesinghsonia', 4),
#  ('@DelhiJalBoard', 4),
#  ('@yadavakhilesh', 4),
#  ('@indiatvnews', 4),
#  ('@ndtvindia', 4),
#  ('@Gurdeepgurus', 4),
#  ('@_ProfAnand', 4),
#  ('#Kejriwal', 4),
#  ('#AnnaHazare', 4),
#  ('#IndiaAgainstCorruption', 4),
#  ('@DayaramDewasi93', 4),
#  ('#Punjab,', 4),
#  ('@ramnikmann', 4),
#  ('@LtGovDelhi', 4),
#  ('#Election2022', 4),
#  ('#aamaadmiparty', 4),
#  ('#Khalistan', 4),
#  ('@CharanRcp441', 4),
#  ('@TimesNow', 3),
#  ('@memeghnad', 3),
#  ('@MediaHarshVT', 3),
#  ('@kpawar944', 3),
#  ('@pkaakki', 3),
#  ('@SudeshPatel', 3),
#  ('@BhupenderKumhar', 3),
#  ('@janta_poll', 3),
#  ('#DelhiRiots', 3),
#  ('#Khalistani', 3),
#  ('@p_sahibsingh', 3),
#  ('#KejriwalExposed', 3),
#  ('@AAPNareshBalyan', 3),
#  ('@souravjain540', 3),
#  ('@HardeepSPuri', 3),
#  ('@Shehzad_Ind', 3),
#  ('@myogiadityanath', 3),
#  ('@DaaruBaazMehta', 3),
#  ('@ZeeNews', 3),
#  ('@DelhiPolice', 3),
#  ('@NIA_India', 3),
#  ('@raghav_chadda', 3),
#  ('@PTI_News', 3),
#  ('@srinivasiyc', 3),
#  ('@ssmpunjab', 3),
#  ('@JoinAAP', 3),
#  ('@KapilMishra_IND', 3),
#  ('#PunjabAssemblyElections2022', 3),
#  ('#AAPPunjab', 3),
#  ('#kejriwalshouldresign', 3),
#  ('#EkMaukaAAPKo', 3),
#  ('@Kishlaysharma', 3),
#  ('#BhagwantMann', 3),
#  ('@JaipurDialogues', 3),
#  ('#NarendraModi', 3),
#  ('#PMModi', 3),
#  ('@TheRahulMehra', 3),
#  ('@jvsk3', 3),
#  ('@BJP4UP', 3),
#  ('@aartic02', 3),
#  ('#SocialMedia', 3),
#  ('@nitinagarwalINC', 3),
#  ('@Harpreet_SinghB', 3),
#  ('@JassiKhangura', 2),
#  ('#AAPisTheChange', 2),
#  ('#PunjabModiNaal', 2),
#  ('@NitinTyagiAAP', 2),
#  ('@AhbaabGrewal', 2),
#  ('@Memeghnad', 2),
#  ('@ChemburAap', 2),
#  ('@tehseenp', 2),
#  ('@htTweets', 2),
#  ('@divs13', 2),
#  ('@GulPanag', 2),
#  ('@DrKumarVishwas,', 2),
#  ('@zoo_bear', 2),
#  ('@abhijitmajumder', 2),
#  ('@apurvasays', 2),
#  ('@Being_Humor', 2),
#  ('@ItsRoshanRai', 2),
#  ('@Morewithshashi', 2),
#  ('@INCDelhi', 2),
#  ('@Oye_Jahazi', 2),
#  ('@dtptraffic', 2),
#  ('@shubhshaurya1', 2),
#  ('@HimeshPJoshi', 2),
#  ('@DrMunishRaizada', 2),
#  ('@TransparencyWS', 2),
#  ('@Untoldind', 2),
#  ('@LambaAlka', 2),
#  ('@HMOIndia', 2),
#  ('@BhagwantMannMP', 2),
#  ('@DrKumarVishwas.', 2),
#  ('@dr_arunkgupta', 2),
#  ('@Hanspalofficial', 2),
#  ('@AjayDutt48', 2),
#  ('@_garrywalia', 2),
#  ('@TOIChandigarh', 2),
#  ('@IYC', 2),
#  ('@plcpunjab', 2),
#  ('#PunjabDiSiyasat', 2),
#  ('#VotanPunjabDiyan', 2),
#  ('#pupulse', 2),
#  ('@officeofssbadal', 2),
#  ('@subham_rwt', 2),
#  ('@AAPGoa', 2),
#  ('#VoteForAAP', 2),
#  ('@bainjal', 2),
#  ('#Khalistani_Kejriwal', 2),
#  ('@Pawankhera', 2),
#  ('@OohLaaLLaa', 2),
#  ('#Mysore', 2),
#  ('#Elections2022', 2),
#  ("@ArvindKejriwal's", 2),
#  ('@AapKaGopalRai', 2),
#  ('@CNNnews18', 2),
#  ('@the_hindu', 2),
#  ('@republic', 2),
#  ('@rubenmasc', 2),
#  ('@AITCofficial', 2),
#  ('@WWF', 2),
#  ('@LamdaSky', 2),
#  ('@VNSBihar', 2),
#  ('@VarunKu38830321', 2),
#  ('#OmmcomNews', 2),
#  ('@ArvindKejriwal’s', 2),
#  ('#IkMaukaAAPNu', 2),
#  ('#EkMaukaBhagwantMaanNu', 2),
#  ('@NehaShalini2', 2),
#  ('@beingarun28', 2),
#  ('@nandtara', 2),
#  ('@RiderIndian08', 2),
#  ('@sashikiran78', 2),
#  ('@ashraf_wani', 2),
#  ('@scchabba', 2),
#  ('#KavirajKumarVishwas', 2),
#  ('#Twitter', 2),
#  ('@rajusvin', 2),
#  ('#CharanjitSinghChanni', 2),
#  ('@PSBrarOfficial', 2),
#  ('@amritabhinder', 2),
#  ('@ajitbhinder', 2),
#  ('@BritSikhAsso', 2),
#  ('@RamiRanger', 2),
#  ('@arifaajakia', 2),
#  ('@Shah_Xina', 2),
#  ('#Fraudjiwal', 2),
#  ('#AAPDePaap', 2),
#  ('@thebharatkhabar', 2),
#  ('@DrBhaskarRaj', 2),
#  ('@YSRCParty', 2),
#  ('@cpimspeak', 2),
#  ('#KumarVishvas', 2),
#  ('@vasigaran20', 2),
#  ('@AapJosephRaja', 2),
#  ('@DrDevakumaar', 2),
#  ('@Akansha03808169', 2),
#  ('@socialjurist', 2),
#  ('@EduMinOfIndia', 2),
#  ('@FreeSpeechNo', 2),
#  ('@SKGupta52156093', 2),
#  ('#arvindkejriwal', 2),
#  ('#punjabelections2022', 2),
#  ('@navneetkansal', 2),
#  ('@janakraj13', 2),
#  ('@RajivRanjanRa16', 2),
#  ('@Manu_Kapil', 2),
#  ('@RahulGandhi"', 2),
#  ('@ndtvfeed', 2),
#  ('@official_dda', 2),
#  ('#Date20022022', 1),
#  ('#HistoricDay', 1),
#  ('#PunjabPeople', 1),
#  ('#CorruptPoliticians', 1),
#  ('#EnMasse', 1),
#  ('@Jhadu,', 1),
#  ('#JoBoleSoNihalSatSriAkal', 1),
#  ('@sharmanagendar', 1),
#  ('@jagadisha1', 1),
#  ('@aayeff1', 1),
#  ('@DeepakBhaardwaj', 1),
#  ('@SaifulJamia', 1),
#  ('#punjab', 1),
#  ('@RajeshS57914578', 1),
#  ('@aimthemovie', 1),
#  ('@amitbag77469682', 1),
#  ('@RituJaz81', 1),
#  ('@KapilMishra_IND.', 1),
#  ('@BefittingFacts', 1),
#  ('@junaizmohammed', 1),
#  ('@RK52720972', 1),
#  ('@24_verun', 1),
#  ('@Devanand_69', 1),
#  ('@vinayak_ramesh', 1),
#  ('@navneetsharma_', 1),
#  ('@Bondrana', 1),
#  ('@AbuAnasAzmi6', 1),
#  ('@payalbhayana', 1),
#  ('@sachintaparia', 1),
#  ('@LocalCircles', 1),
#  ('@AnilaSingh_BJP', 1),
#  ('#TalkToBhupen', 1),
#  ('@bhupendrachaube', 1),
#  ('#Nothing', 1),
#  ('#Khalistan.”', 1),
#  ('@AltNews', 1),
#  ('@free_thinker', 1),
#  ('#modi', 1),
#  ('@Pousali32628329', 1),
#  ('#KhalistaniKejriwal', 1),
#  ('@vaibhavUP65', 1),
#  ('@PALVIZOO', 1),
#  ('@Kodungolan737', 1),
#  ('@PostTruthIndia', 1),
#  ('@SinghPunjabi05', 1),
#  ('@poonam_botre', 1),
#  ('#justintrueadu', 1),
#  ('@dna', 1),
#  ('#Punjab!', 1),
#  ('@Muzzris', 1),
#  ('@gulati_lavi', 1),
#  ('@SimmiAhuja_', 1),
#  ('@anjilikkan', 1),
#  ('@AAPMedia', 1),
#  ('@Ashish82_Delhi', 1),
#  ('#DelhiModel', 1),
#  ('@Managerzonal', 1),
#  ('@AbrarPasha6', 1),
#  ('@SpiritOfCongres', 1),
#  ('@RajatSharmaLive', 1),
#  ('@ADDYYGUPTAA', 1),
#  ('@iAlokAgarwal', 1),
#  ('@5SaumyaS', 1),
#  ('@JhaSanjay', 1),
#  ('@thekiranbedi', 1),
#  ('@Gupta_ReenaG', 1),
#  ('@vishalgoyal28', 1),
#  ('@iAroraDeepak', 1),
#  ('@BHARATS2701', 1),
#  ('#aap', 1),
#  ('#Confidence', 1),
#  ('#Honesty', 1),
#  ('#IChooseAAP', 1),
#  ('@IYCPunjab', 1),
#  ('@TajinderBagga', 1),
#  ('@rishibagree', 1),
#  ('@KitanuKiller', 1),
#  ('#JammuAndKashmir', 1),
#  ('@MYounisNaik', 1),
#  ('@preetiagr123', 1),
#  ('@charanjee', 1),
#  ('#support', 1),
#  ('@Kp31368223', 1),
#  ('@monicavaneet', 1),
#  ('@AnilKapoor', 1),
#  ('#Nayak', 1),
#  ('@sowmiyasid', 1),
#  ('@RajeshTaurus71', 1),
#  ('@akhilpachori', 1),
#  ('@pinkysi40475597', 1),
#  ('@rajkshroff', 1),
#  ('@bspindia', 1),
#  ('#PunjabElection', 1),
#  ('#AAPwithterrorist', 1),
#  ('@HasanSafin', 1),
#  ('@TwitterIndia', 1),
#  ('@propjoebmore', 1),
#  ('#BigExpose', 1),
#  ('#HimantaBiswaSarma', 1),
#  ('@JPNadda', 1),
#  ('@congress_', 1),
#  ('@jagdeep_goldy', 1),
#  ('@roshankar', 1),
#  ('@AAPPunjab,', 1),
#  ('#Vyavasta', 1),
#  ('#P_AAP', 1),
#  ('@coolfrnds4u', 1),
#  ('@AishwaryVerma9', 1),
#  ('#RejectHate', 1),
#  ('@smartmanishk', 1),
#  ('@notdatdeshbhakt', 1),
#  ('@RishikeshLaw', 1),
#  ('@MKennley', 1),
#  ('#aamadmimovement', 1),
#  ('@AAPMULUND1', 1),
#  ('#BabaRKB', 1),
#  ('@manojagrawal73', 1),
#  ('#UPElections', 1),
#  ('#SamajwadiParty', 1),
#  ('#BSP', 1),
#  ('#socialmediamarketing', 1),
#  ('#UPElection2022', 1),
#  ('#', 1),
#  ('@MLA_NareshYadav', 1),
#  ('@RenukaCCongress', 1),
#  ('@AamAadmiParty:', 1),
#  ('#AAPWinsPunjab', 1),
#  ('#ElectionsWithMC:', 1),
#  ('@BJP4India’s', 1),
#  ('#kaamKirajneeti', 1),
#  ('#TraitorArvindKejriwal', 1),
#  ('#GaddarArvindKejriwal', 1),
#  ('@ArvindKejriwal.', 1),
#  ('@PunjabGovtIndia', 1),
#  ('@chitraaum', 1),
#  ('@anjanaomkashyap', 1),
#  ('@SwetaSinghAT', 1),
#  ('@TV9Bharatvarsh', 1),
#  ('@Republic_Bharat', 1),
#  ('@AAPGujarat', 1),
#  ('#JaagoVoterJaago😳😳😳', 1),
#  ('#CongressSold', 1),
#  ('#VoteForJhadu', 1),
#  ('@OpIndia_in', 1),
#  ('@RaghavChadha', 1),
#  ('@DrKumarVishwas👇', 1),
#  ('@AHindinews', 1),
#  ('@IndEditorsGuild', 1),
#  ('#GodiMedia', 1),
#  ('@INCBihar', 1),
#  ('@Sustain28995791', 1),
#  ('@SureshChavhanke', 1),
#  ('@sudhirchaudhary', 1),
#  ('@AshokShrivasta6', 1),
#  ('@NewsNationTV', 1),
#  ('@MIB_India', 1),
#  ('@ianuragthakur', 1),
#  ('@aimim_national', 1),
#  ('@trspartyonline', 1),
#  ('@KTRTRS', 1),
#  ('@RanaAyyub', 1),
#  ('@kanhaiyakumar', 1),
#  ('@bassi_gogi', 1),
#  ('@ALOKdelhi6', 1),
#  ('@Tarique_78', 1),
#  ('@naijilnj', 1),
#  ('#Rajneeti', 1),
#  ('#KaamKiRajneeti!!', 1),
#  ('@HindutvaHind', 1),
#  ('#anaganwadi', 1),
#  ('@nitin_gadkari', 1),
#  ('@BBCHindi', 1),
#  ('@sauruvarya15', 1),
#  ('@babu557869', 1),
#  ('@teamrrg', 1),
#  ('#Vote', 1),
#  ('@nustamemes7', 1),
#  ('@PraveenDabas14', 1),
#  ('@AapkiBandana', 1),
#  ('@ipathak25', 1),
#  ('@indosecular', 1),
#  ('@churn_ever', 1),
#  ('@AAPNagpur', 1),
#  ('@SatnamPradhaan', 1),
#  ('@aap', 1),
#  ('@peta', 1),
#  ('@PetaIndia', 1),
#  ('@PETAUK', 1),
#  ('@petatodd', 1),
#  ('@ChriestyAngel', 1),
#  ('@priyankac19', 1),
#  ('@khanumarfa', 1),
#  ('@ReallySwara', 1),
#  ('@Rofl_Vishvas', 1),
#  ('@punjabaamaadmi', 1),
#  ('#AAP_BJP_exposed', 1),
#  ('@Shomes_quest', 1),
#  ('@shubh_ind', 1),
#  ('@indigokores', 1),
#  ('#PolstratUpdate:', 1),
#  ('#Punjab."', 1),
#  ('@DograTishaa', 1),
#  ('@IndianNationalC', 1),
#  ('@BJP4Chandigarh', 1),
#  ('@Ranchiwasi', 1),
#  ('@deeppant2', 1),
#  ('#Controverses2022.', 1),
#  ('@NewsArenaIndia', 1),
#  ('@gssjodhpur', 1),
#  ('#PunjabPolls2022', 1),
#  ('#PunjabAssemblyElections', 1),
#  ('@TOMrajiyo29', 1),
#  ('@FellowcitizenEs', 1),
#  ('#PunjabPolls', 1),
#  ('#PunjabBJP', 1),
#  ('#PunjabCongress', 1),
#  ('@AryaRaushni', 1),
#  ('@Ankitkadian_', 1),
#  ('@DeccanHerald', 1),
#  ('@AAPReport', 1),
#  ('@GSChaudhary007', 1),
#  ('#Aarey_Forest', 1),
#  ('#AAP_Mumbai', 1),
#  ('@Gss_Views', 1),
#  ('@lokeshbisht_', 1),
#  ('@SpeakingTigers', 1),
#  ('#Khalistani_Kejriwal.', 1),
#  ('@AamAadmiParty.😁😁😁', 1),
#  ('@veerappavenkap1', 1),
#  ('@minicnair', 1),
#  ('@hello_nicks', 1),
#  ('#CM', 1),
#  ('@ppbajpai', 1),
#  ('@INCIndia,', 1),
#  ('@GauravPandhi', 1),
#  ('@SachiRath', 1),
#  ('@mssirsa', 1),
#  ('@sain_mamraj', 1),
#  ('@rajrn99', 1),
#  ('@ApnaPanjabParty', 1),
#  ('@TheKillerX12', 1),
#  ('@imjrocky02', 1),
#  ('@DrKumarViswas', 1),
#  ('@mishrarocky', 1),
#  ('#आप', 1),
#  ('@Libertarian196', 1),
#  ('@tanaya137', 1),
#  ('@ZeeNewsEnglish', 1),
#  ('@TheLallantop', 1),
#  ('@BBCWorld', 1),
#  ('@ankushpal2001', 1),
#  ('@Sanghi_Aapian', 1),
#  ('@Mystic_Soul25', 1),
#  ('@ShwetaIndia1', 1),
#  ('@Vaibhav_AAP', 1),
#  ('@AapFriend', 1),
#  ('@iqasifpdkt', 1),
#  ('@XandryCSGO', 1),
#  ('#SupremeCourt', 1),
#  ('#AntiNational', 1),
#  ('#AntiIndiaElements.', 1),
#  ('@JSvasan', 1),
#  ('@blsanthosh', 1),
#  ('@BJP4Goa', 1),
#  ('@BJP4Manipur', 1),
#  ('@aapkaprithvi', 1),
#  ('@AAPKarnataka', 1),
#  ('@AAPBangalore', 1),
#  ('#AAMAADMIPARTY"', 1),
#  ('#aap_bjp_exposed', 1),
#  ('#JKElections2022!', 1),
#  ('@reachind_uk', 1),
#  ('@changu311', 1),
#  ("#Kejriwal's", 1),
#  ('@ilob2bforgotten', 1),
#  ('@ECISVEEP', 1),
#  ('#RajyaSabha', 1),
#  ('#ChandaBabu', 1),
#  ('#Breakingnews', 1),
#  ('#Indiapolitics', 1),
#  ('#AndhraPolitics', 1),
#  ('#NewsFeed', 1),
#  ('#Mamata', 1),
#  ('#Hindus', 1),
#  ('#Pakistani,', 1),
#  ('#FaceBook', 1),
#  ('@madversity', 1),
#  ('@Jatinde94596131', 1),
#  ('@KotakCares', 1),
#  ('@udaykotak', 1),
#  ('@kotak811', 1),
#  ('@AnilSinghvi_', 1),
#  ('@TheVijayMallya', 1),
#  ('@bankscam', 1),
#  ('@IndBanegaManch', 1),
#  ('@CMOGuj', 1),
#  ('@normalpeople', 1),
#  ('#Anganwadi', 1),
#  ('#fraudjiwal', 1),
#  ('#LestWeForget', 1),
#  ('#Fraud', 1),
#  ('#Aarey', 1),
#  ('@AareyForest', 1),
#  ('@absolutpop', 1),
#  ('@saveaarey', 1),
#  ('#Mumbai', 1),
#  ('#savetree', 1),
#  ('#AdaniPower', 1),
#  ('@PuriVirender', 1),
#  ('#ElectionsWithNDTV', 1),
#  ('#SharaabNagri', 1),
#  ('#YouTube', 1),
#  ('#IkMaukaBhagwantMannNu', 1),
#  ('@drkumarvishwas', 1),
#  ('#brakingINDIA', 1),
#  ('#PUNJAB', 1),
#  ('@divya_amanna', 1),
#  ('@Barmer_Harish', 1),
#  ('@jsn_jsk', 1),
#  ('@humanly_we', 1),
#  ('@ShriniwasMantri', 1),
#  ('@shamshad031463', 1),
#  ('@madshumanbeing1', 1),
#  ('@eumesmo_pirates', 1),
#  ('@ProfSK5', 1),
#  ('@Rup_INC', 1),
#  ('@rajepravin1', 1),
#  ('@Pratik_INC', 1),
#  ('@anisaz9_basit', 1),
#  ('@Humhongekamyab1', 1),
#  ('@AmardeepSBrar1', 1),
#  ('@AAPKA_RK', 1),
#  ('@AapActive123', 1),
#  ('@AAPlogical', 1),
#  ('@grow24by7', 1),
#  ('#PanIndiaLeader', 1),
#  ('#KEJRIWAL', 1),
#  ('#MyVoteForCongress', 1),
#  ('@BJP4India.', 1),
#  ('@anuragteddy', 1),
#  ('@shoumendu989', 1),
#  ('#aap_ke_paap', 1),
#  ('#congressmeanscorruption', 1),
#  ('#kick_congress_movement', 1),
#  ('@richapandey', 1),
#  ('@BJP4Delhi', 1),
#  ('@adeshguptabjp', 1),
#  ('@siddharthanbjp', 1),
#  ('@naveenjindalbjp', 1),
#  ('@PittieAditya', 1),
#  ('@amitmalviya', 1),
#  ('@', 1),
#  ('@dsajames11', 1),
#  ('@TheTanveerAhmed', 1),
#  ('@JanataDal_S', 1),
#  ('@samajwadiparty', 1),
#  ('@ShivSena', 1),
#  ('@JaiTDP', 1),
#  ('@Richard93205519', 1),
#  ('#ShiromaniAkaliDal,', 1),
#  ('#AssemblyElection2022', 1),
#  ('@Druzhokkoba', 1),
#  ('#Punjab,like', 1),
#  ('@DrKumarVishwas,the', 1),
#  ('@Kumar4636', 1),
#  ('@nsitharaman', 1),
#  ('@dpradhanbjp', 1),
#  ('#TreatLongCovid', 1),
#  ('#antinationals!', 1),
#  ('#Covid', 1),
#  ('@vvmspeaks', 1),
#  ('@brijeshgoyalaap', 1),
#  ('@VikasGoelAAP', 1),
#  ('@Parth_Pareek20', 1),
#  ('@GoldyDS_Dhuri', 1),
#  ('#AAPiyans', 1),
#  ('#ThePrintPod', 1),
#  ("@NikhilRampal1's", 1),
#  ('@gautameeh_', 1),
#  ('#RajneetiBadalneAayaaHai.', 1),
#  ('#Khalistan.', 1),
#  ('@LalatenduSpeaks', 1),
#  ('@News18Guj', 1),
#  ('@JarnailSinghAAP', 1),
#  ('@ippatel', 1),
#  ('#Punjab.(10', 1),
#  ('@Jackie59080284', 1),
#  ('@BritIndianVoice', 1),
#  ('@KaiheAwan', 1),
#  ('@RSSorg', 1),
#  ('@Loquacious_Lion', 1),
#  ('#kumarvishvas', 1),
#  ('#kejriwal', 1),
#  ('@akm1410', 1),
#  ('@me_skullz', 1),
#  ('@aiionq', 1),
#  ('@AamAadmiParty,@KDF_LoL,@DDARI23', 1),
#  ('@2HJB_S,', 1),
#  ('@ggain90,', 1),
#  ('@afectadosporcdo,', 1),
#  ('@lluvia_doyoung', 1),
#  ('#PunjabElections2022:', 1),
#  ('@kabir_naqvi', 1),
#  ('#PollsWithIndiaAhead', 1),
#  ('@news24tvchannel', 1),
#  ('@logicalindianz', 1),
#  ('@politics_2019_', 1),
#  ('@PPSbtp', 1),
#  ('@arungiri', 1),
#  ('@bothrapawan53', 1),
#  ('@bole_bharat', 1),
#  ('@AAPMiraBhy', 1),
#  ('@rajeshsepia', 1),
#  ('@ranvijaylive', 1),
#  ('#ANI', 1),
#  ('#AapDePaap', 1),
#  ('@NarendraModi', 1),
#  ('@DainikBhaskar', 1),
#  ('@TheCEOPunjab', 1),
#  ('@Aappunjab', 1),
#  ('@AshwiniUpadhyay', 1),
#  ('#bhagwantmann', 1),
#  ('#UttarPradesh', 1),
#  ('#Bihar', 1),
#  ('@pramila2710', 1),
#  ('@AnkitLal', 1),
#  ('@samitakaur74', 1),
#  ('@AdnanAliKhan555', 1),
#  ('@BabaGodzillaJi', 1),
#  ('#khalivsMahal', 1),
#  ('#heavyvotechampionship', 1),
#  ('#Pakistan', 1),
#  ('#India', 1),
#  ('#OMG', 1),
#  ('#NeverTrustKejriwal', 1),
#  ('@MudasirMagrey1', 1),
#  ('@Newindianxpress,', 1),
#  ('@TheMornStandard,', 1),
#  ('@gsvasu_TNIE,', 1),
#  ('@khogensingh1', 1),
#  ('@rahulroushan', 1),
#  ('@kanikKkr', 1),
#  ('@judedavid21', 1),
#  ('#KejriwalMohallaTheka', 1),
#  ('#ProPunjabTv', 1),
#  ('#arvind', 1),
#  ('#bhagwant', 1),
#  ('#RavidasJayanti2022', 1),
#  ('@RemindMe_OfThis', 1),
#  ('#GoaElections2022', 1),
#  ('#ChowChowbath', 1),
#  ('@DaaruBaazMehta:', 1),
#  ('#AamAadmi', 1),
#  ('#PunjabCongressLiquorMafia', 1),
#  ('#PunjabRisingWithMODI', 1),
#  ('@Sachin40758588', 1),
#  ('@gupta_iitdelhi', 1),
#  ('@PbpandeyB', 1),
#  ('@mr_mayank', 1),
#  ('#declare', 1),
#  ('@Rohit245_', 1),
#  ('@budh_principal-', 1),
#  ('#AAM', 1),
#  ('@Gauravyadav3275', 1),
#  ('#congresshiayegi', 1),
#  ('@SmallBoxIndia', 1),
#  ('@AapHonest', 1),
#  ('#BharatiyaJanataParty', 1),
#  ('#PathankotRally', 1),
#  ('@indSupremeCourt', 1),
#  ('#DelhiPogram20202…Don’t', 1),
#  ('@MrSinha_', 1),
#  ('@mgmnair', 1),
#  ('@arvindkejriwal', 1),
#  ('@AwadheshKumarG1', 1),
#  ('@IskconInc', 1),
#  ('@INCUPEast', 1),
#  ('@INCGujarat', 1),
#  ('#Punjabi', 1),
#  ('@Lipikaanaik', 1)]
