# %%
import pandas as pd

# %%
df = pd.read_csv("data/samajwadi/samajwadi_2022-02-19.csv")

# %%
alltxt = df['tweet'].to_list()

# %%
allwrds = {}
for txt in alltxt:
    l = txt.split()
    for w in l:
        if w in allwrds:
            allwrds[w] += 1
        else:
            allwrds[w] = 1

# %%
sorted_wrds = sorted(allwrds.items(), key=lambda x: x[1], reverse=True)

# %%
sorted_wrds = [w for w in sorted_wrds if w[0][0] == '@' or w[0][0] == '#']

# %%
sorted_wrds
# Out:
# [('@samajwadiparty', 363),
#  ('@yadavakhilesh', 131),
#  ('@MediaCellSP', 30),
#  ('@BJP4India', 28),
#  ('#UttarPradeshElections2022', 24),
#  ('@BJP4UP', 23),
#  ('@dimpleyadav', 20),
#  ('@myogiadityanath', 19),
#  ('@INCIndia', 18),
#  ('@juhiesingh', 16),
#  ('@priyankagandhi', 15),
#  ('@INCUttarPradesh', 13),
#  ('@ShreyaVermaSP', 13),
#  ('#UPElections2022', 12),
#  ('#UttarPradesh', 12),
#  ('#BJP', 11),
#  ('@SPMahilaSabha', 11),
#  ('#UttarPradeshElections', 10),
#  ('#SamajwadiParty', 10),
#  ("#UttarPradesh's", 9),
#  ('#AkhileshYadav', 8),
#  ('@Tejasvi_Surya', 8),
#  ('@asadowaisi', 7),
#  ('@oprajbhar', 7),
#  ('@RajeevRai', 7),
#  ('@SBSP4INDIA', 6),
#  ('@RLDparty', 6),
#  ('@aimim_national', 6),
#  ('#YogiAdityanath', 5),
#  ('@jayantrld', 5),
#  ('#PlotToKillModi', 5),
#  ('#UttarPradeshElection2022', 5),
#  ('@nidhisamajwadi', 5),
#  ('@rohini_sgh', 5),
#  ('@ramakantyadavmp', 5),
#  ('@AamAadmiParty', 5),
#  ('@sbsp4ghazipur', 5),
#  ('@Kisanektamorcha', 5),
# ...
